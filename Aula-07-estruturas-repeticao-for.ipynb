# %% [markdown]
# # Exercícios
#
# ## Estruturas de Repetição II
# ### Ciclos For

# %% [markdown]
# 1. Números primos.
#
# Criar um programa em Python que utilize um loop for e listas para identificar e exibir todos os números primos entre 1 e um limite definido pelo usuário.
#
# **Instruções**:
#
# - Crie uma lista vazia: No início do programa, declare uma lista vazia que armazenará os números primos encontrados.
# - Obtenha o limite do usuário: Utilize a função input() para solicitar ao usuário que digite o limite superior da faixa de números a ser analisada. Armazene esse valor em uma variável.
# - Loop for: Utilize um loop for para iterar sobre os números entre 2 e o limite definido pelo usuário (inclusive).
# - Verificação de número primo: Dentro do loop for, implemente uma lógica para verificar se o número atual é primo. Um número primo é divisível apenas por 1 e por ele mesmo.
# - Adicionando à lista: Se o número atual for um número primo, adicione-o à lista de números primos criada anteriormente.
# - Exibir resultados: Após o término do loop for, utilize a função print() para exibir a lista de números primos encontrados.

# %%
# Resposta questão 1

# %% [markdown]
# 2.  Agenda Telefônica
#
# Criar um programa em Python que utilize um loop for e dicionários para gerenciar uma agenda telefônica simples.
#
# **Instruções:**
#
# Crie um dicionário vazio: No início do programa, declare um dicionário vazio que armazenará os contatos da agenda. Cada chave do dicionário representará o nome do contato e o valor associado será o número de telefone.
#
# Menu principal: Apresente ao usuário um menu com as seguintes opções:
#
# - 1. Adicionar Contato
# - 2. Buscar Contato
# - 3. Remover Contato
# - 4. Listar Contatos
# - 0. Sair
#
# Opções do menu: Utilize a estrutura while para repetir a exibição do menu principal e capturar a escolha do usuário através da função input().
#
# **Adicionar Contato:**
#
# - Solicite ao usuário o nome e o número de telefone do novo contato.
# - Verifique se o nome do contato já existe no dicionário.
# - Se o nome não existir, adicione o novo contato ao dicionário utilizando o nome como chave e o número de telefone como valor.
# - Se o nome já existir, informe ao usuário que o contato já está na agenda.
#
# **Buscar Contato:**
#
# - Solicite ao usuário o nome do contato que deseja buscar.
# - Verifique se o nome do contato existe no dicionário.
# - Se o contato existir, exiba o seu número de telefone.
# - Se o contato não existir, informe ao usuário que o contato não foi encontrado.
#
# **Remover Contato:**
#
# - Solicite ao usuário o nome do contato que deseja remover.
# - Verifique se o nome do contato existe no dicionário.
# - Se o contato existir, remova-o do dicionário.
# - Se o contato não existir, informe ao usuário que o contato não foi encontrado.
#
# **Listar Contatos:**
#
# - Utilize um loop for para iterar sobre os nomes dos contatos no dicionário.
# - Para cada contato, exiba seu nome e número de telefone.

# %%
# Resposta questão 2

# %% [markdown]
# 3. Sistema de votação
#
# Criar um programa em Python que utilize um dicionário e listas para simular um processo de votação em uma eleição, com candidatos, partidos e votos.
#
# **Instruções:**
#
# **Estrutura de dados:**
#
# - Utilize um dicionário principal chamado eleicao para armazenar todas as informações da eleição.
# - A chave principal do dicionário eleicao será a string "candidatos".
# - O valor associado à chave "candidatos" será uma lista de dicionários, cada um contendo as informações de um candidato:
#
#  - numero: Número do candidato (int).
#  - nome: Nome do candidato (string).
#  - partido: Nome do partido do candidato (string).
#  - votos: Quantidade de votos recebidos pelo candidato (int, inicializado em 0).
#
# - Crie outro dicionário chamado votos_por_partido para armazenar a contagem de votos por partido.
# - As chaves do dicionário votos_por_partido serão os nomes dos partidos (strings).
# - O valor associado a cada nome de partido será uma lista de dicionários, cada um contendo os votos por candidato daquele partido:
#  - numero: Número do candidato (int).
#  - votos: Quantidade de votos recebidos pelo candidato naquele partido (int, inicializado em 0).
#
# **Menu principal:**
#
# Apresente ao usuário um menu com as seguintes opções:
#
# 1. Cadastrar Candidato
# 2. Votar
# 3. Exibir Estatísticas Parciais
# 4. Finalizar Votação e Mostrar Resultado
# 0. Sair
#
# Opções do menu:
#
#  - Utilize a estrutura while para repetir a exibição do menu principal e capturar a escolha do usuário através da função input().
#
# **Cadastrar Candidato:**
#
#  - Solicite ao usuário o número, nome, partido do novo candidato.
#  - Verifique se o número do candidato já existe na lista de candidatos do dicionário eleicao utilizando a estrutura for e a instrução if.
#  - Se o número não existir, adicione um novo dicionário à lista de candidatos no dicionário eleicao com as informações do candidato (numero, nome, partido, votos=0).
#  - Se o número já existir, informe ao usuário que o número já está em uso.
#
# **Votar:**
#
#  - Exiba uma lista numerada com os números, nomes e partidos de todos os candidatos cadastrados.
#  - Solicite ao usuário o número do candidato em que deseja votar.
#  - Utilize o número do candidato para obter as informações do candidato real.
#  - Verifique se o código do candidato existe na lista de candidatos do dicionário eleicao.
#  - Se o código existir, incremente o contador de votos do candidato no dicionário eleicao.
#  - Atualize a contagem de votos por partido no dicionário votos_por_partido.
#  - Agradeça ao usuário por votar.
#
# **Exibir Estatísticas Parciais:**
#
#  - Exiba o total de votos apurados até o momento.
#  - Utilize loops for para iterar sobre os candidatos e partidos:
#  - Para cada candidato, exiba seu número, nome, partido e quantidade de votos recebidos.
#  - Para cada partido, exiba o nome do partido, o total de votos recebidos e os votos de cada candidato daquele partido.
#
# **Finalizar Votação e Mostrar Resultado:**
#
#  - Informe ao usuário que a votação foi finalizada.
#  - Utilize loops for para identificar o vencedor e exibir os resultados:
#
# **Vencedor:**
#
#  - Identifique o candidato com o maior número de votos (vencedor).
#  - Exiba o nome, partido, quantidade de votos totais e porcentagem de votos do candidato vencedor.
#
# **Demais Candidatos:**
#
#  - Exiba os demais candidatos em ordem decrescente de votos.
#  - Para cada candidato, exiba seu nome, partido, quantidade de votos totais e porcentagem de votos.
#
# **Estatísticas por Partido:**
#
# - Exiba o nome do partido com o maior número de votos totais.
# - Para cada partido, exiba o nome do partido, o total de votos recebidos e a porcentagem de votos em relação ao total.

# %%
# Resposta questão 3

# %% [markdown]
# 4. Você possui uma lista de dicionários que representam informações sobre pessoas, incluindo nome, idade e cidade. Seu objetivo é criar uma nova lista contendo apenas as pessoas que residem em uma cidade específica e que possuem idade maior ou igual a 18 anos.
#
# ```python
# pessoas = [
#     {"nome": "João", "idade": 25, "cidade": "João Pessoa"},
#     {"nome": "Maria", "idade": 17, "cidade": "Recife"},
#     {"nome": "Pedro", "idade": 30, "cidade": "João Pessoa"},
#     {"nome": "Ana", "idade": 22, "cidade": "Salvador"},
# ]
# ```
#
# Utilize _list comprehensions_ e estrutura `if` para:
#
# Criar a Lista Filtrada:
#
# - Percorra a lista original de pessoas.
# - Para cada pessoa:
#     - Verifique se a cidade da pessoa é igual à cidade especificada.
#     - Verifique se a idade da pessoa é maior ou igual a 18 anos.
#     - Se ambas as condições forem verdadeiras, adicione a pessoa à nova lista filtrada.
#
# Exibir o Resultado:
#
# - Apresente a nova lista filtrada contendo apenas as pessoas que atendem aos critérios especificados.

# %%
# Resposta questão 4
